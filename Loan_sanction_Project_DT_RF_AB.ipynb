# %% [markdown]
# # Loan Senction Project

# %%
#Importing Library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Datacouncil11/Loan_sancion_project/main/loan-train.csv')

# %%
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %% [markdown]
# Exploratory Data Analysis

# %%
df.shape
# Out:
# (614, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    object
#  2   Married            611 non-null    object
#  3   Dependents         599 non-null    object
#  4   Education          614 non-null    object
#  5   Self_Employed      582 non-null    object
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    object
#  12  Loan_Status        614 non-null    object
# dtypes: float64(4), int64(1), object(8)
# memory usage: 62.5+ KB

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female', nan], dtype=object)

# %%
d1 = df

# %%
d1.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
d1.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
for i in d1.columns:
    print("Column Name", i)
    print('Unique values in',i,d1[i].unique())
    print("*"*60)
# Out:
# Column Name Loan_ID
# Unique values in Loan_ID ['LP001002' 'LP001003' 'LP001005' 'LP001006' 'LP001008' 'LP001011'
#  'LP001013' 'LP001014' 'LP001018' 'LP001020' 'LP001024' 'LP001027'
#  'LP001028' 'LP001029' 'LP001030' 'LP001032' 'LP001034' 'LP001036'
#  'LP001038' 'LP001041' 'LP001043' 'LP001046' 'LP001047' 'LP001050'
#  'LP001052' 'LP001066' 'LP001068' 'LP001073' 'LP001086' 'LP001087'
#  'LP001091' 'LP001095' 'LP001097' 'LP001098' 'LP001100' 'LP001106'
#  'LP001109' 'LP001112' 'LP001114' 'LP001116' 'LP001119' 'LP001120'
#  'LP001123' 'LP001131' 'LP001136' 'LP001137' 'LP001138' 'LP001144'
#  'LP001146' 'LP001151' 'LP001155' 'LP001157' 'LP001164' 'LP001179'
#  'LP001186' 'LP001194' 'LP001195' 'LP001197' 'LP001198' 'LP001199'
#  'LP001205' 'LP001206' 'LP001207' 'LP001213' 'LP001222' 'LP001225'
#  'LP001228' 'LP001233' 'LP001238' 'LP001241' 'LP001243' 'LP001245'
#  'LP001248' 'LP001250' 'LP001253' 'LP001255' 'LP001256' 'LP001259'
# ...

# %%
for i in d1.columns:
    print('Column Name is ',i)
    print("Null values in",i,d1[i].isnull().sum())
    print("*"*60)
# Out:
# Column Name is  Loan_ID
# Null values in Loan_ID 0
# ************************************************************
# Column Name is  Gender
# Null values in Gender 13
# ************************************************************
# Column Name is  Married
# Null values in Married 3
# ************************************************************
# Column Name is  Dependents
# Null values in Dependents 15
# ************************************************************
# Column Name is  Education
# Null values in Education 0
# ************************************************************
# Column Name is  Self_Employed
# Null values in Self_Employed 32
# ************************************************************
# Column Name is  ApplicantIncome
# Null values in ApplicantIncome 0
# ************************************************************
# Column Name is  CoapplicantIncome
# Null values in CoapplicantIncome 0
# ************************************************************
# ...

# %%
for i in d1.columns:
    print('Column Name is',i)
    print(d1[i].describe())
    print("*"*60)
# Out:
# Column Name is Loan_ID
# count          614
# unique         614
# top       LP001002
# freq             1
# Name: Loan_ID, dtype: object
# ************************************************************
# Column Name is Gender
# count      601
# unique       2
# top       Male
# freq       489
# Name: Gender, dtype: object
# ************************************************************
# Column Name is Married
# count     611
# unique      2
# top       Yes
# freq      398
# Name: Married, dtype: object
# ************************************************************
# Column Name is Dependents
# count     599
# unique      4
# top         0
# freq      345
# Name: Dependents, dtype: object
# ************************************************************
# Column Name is Education
# count          614
# unique           2
# top       Graduate
# freq           480
# Name: Education, dtype: object
# ************************************************************
# Column Name is Self_Employed
# ...

# %% [markdown]
# Duplicate values

# %%
df[d1.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Loan_ID, Gender, Married, Dependents, Education, Self_Employed, ApplicantIncome, CoapplicantIncome, LoanAmount, Loan_Amount_Term, Credit_History, Property_Area, Loan_Status]
# Index: []

# %% [markdown]
# Filling misssing values

# %%
d1['Gender'].isnull().sum()
# Out:
# 13

# %%
d1['Gender'].mode()
# Out:
# 0    Male
# Name: Gender, dtype: object

# %%
mode_gender = d1['Gender'].mode()[0]

# %%
mode_gender
# Out:
# 'Male'

# %%
d1['Gender'].fillna(mode_gender,inplace=True)

# %%
d1['Gender'].isnull().sum()
# Out:
# 0

# %%
d1['Married'].isnull().sum()
# Out:
# 3

# %%
mode_married = d1['Married'].mode()[0]

# %%
mode_married
# Out:
# 'Yes'

# %%
df['Married'].fillna(mode_married,inplace=True)
df['Married'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Dependent & Education

# %%
mode_dependents = df['Dependents'].mode()[0]

# %%
mode_dependents
# Out:
# '0'

# %%
d1['Dependents'].fillna(mode_dependents, inplace=True)
d1['Dependents'].isnull().sum()
# Out:
# 0

# %%
mode_education = df['Education'].mode()[0]
mode_education
# Out:
# 'Graduate'

# %%
d1['Education'].fillna(mode_education, inplace=True)
d1['Education'].isnull().sum()
# Out:
# 0

# %%
mode_emp = d1['Self_Employed'].mode()[0]
mode_emp
# Out:
# 'No'

# %%
d1['Self_Employed'].fillna(mode_emp, inplace=True)
d1['Self_Employed'].isnull().sum()
# Out:
# 0

# %%
mean_loan_amount = d1['LoanAmount'].mean()

# %%
mean_loan_amount
# Out:
# 146.41216216216216

# %%
d1['LoanAmount'].fillna(mean_loan_amount, inplace=True)
d1['LoanAmount'].isnull().sum()
# Out:
# 0

# %%
Loan_A_T_Mode = d1['Loan_Amount_Term'].mode()[0]

# %%
d1['Loan_Amount_Term'].fillna(Loan_A_T_Mode, inplace=True)
d1['Loan_Amount_Term'].isnull().sum()
# Out:
# 0

# %%
credit_mode = d1['Credit_History'].mode()[0]

# %%
d1['Credit_History'].fillna(credit_mode, inplace=True)

# %%
d1['Credit_History'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Mapping

# %%
from sklearn.preprocessing import LabelEncoder

# %% [markdown]
# Applying label encodng

# %%
label_encoder = LabelEncoder()

# %%
d1['Gender_Label'] = label_encoder.fit_transform(d1['Gender'])

# %%
d1['Married_Label'] = label_encoder.fit_transform(d1['Married'])

# %%
d1['Dependents_Label'] = label_encoder.fit_transform(d1['Dependents'])

# %%
d1['Education_Label'] = label_encoder.fit_transform(d1['Education'])

# %%
d1['Self_Emp_Label'] = label_encoder.fit_transform(d1['Self_Employed'])

# %%
d1['Credit_history_Label'] = label_encoder.fit_transform(d1['Credit_History'])

# %%
d1['Property_area_Label'] = label_encoder.fit_transform(d1['Property_Area'])

# %%
# Removing Colums

# %%
d1.drop('Gender',axis=1,inplace=True)

# %%
d1.drop('Married',axis=1,inplace=True)
d1.drop('Dependents',axis=1,inplace=True)
d1.drop('Self_Employed',axis=1,inplace=True)
d1.drop('Credit_History',axis=1,inplace=True)
d1.drop('Property_Area',axis=1,inplace=True)

# %%
d1.drop('Education',axis=1,inplace=True)

# %%
d1['Loan_status_1'] = d1['Loan_Status']

# %%
d1.drop('Loan_Status',axis=1,inplace=True)

# %%
d1.drop('Loan_ID',axis=1,inplace=True)

# %%
d1.head()
# Out:
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0  146.412162             360.0
# 1             4583             1508.0  128.000000             360.0
# 2             3000                0.0   66.000000             360.0
# 3             2583             2358.0  120.000000             360.0
# 4             6000                0.0  141.000000             360.0
#
#    Gender_Label  Married_Label  Dependents_Label  Education_Label  \
# 0             1              0                 0                0
# 1             1              1                 1                0
# 2             1              1                 0                0
# 3             1              1                 0                1
# 4             1              0                 0                0
#
#    Self_Emp_Label  Credit_history_Label  Property_area_Label Loan_status_1
# 0               0                     1                    2             Y
# ...

# %% [markdown]
# dependents and in dependents

# %%
X = d1.iloc[:,:-1]

# %%
y = d1.iloc[:, -1]

# %%
y.head()
# Out:
# 0    Y
# 1    N
# 2    Y
# 3    Y
# 4    Y
# Name: Loan_status_1, dtype: object

# %%
d1['Dependents_Label'].unique()
# Out:
# array([0, 1, 2, 3])

# %%
# Diving data into train test split

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.33, random_state=42)

# %%
X_train.head()
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 244             3406             4417.0       123.0             360.0
# 393             1993             1625.0       113.0             180.0
# 310             2917                0.0        84.0             360.0
# 408             8300                0.0       152.0             300.0
# 572            16666                0.0       275.0             360.0
#
#      Gender_Label  Married_Label  Dependents_Label  Education_Label  \
# 244             1              1                 0                1
# 393             1              1                 2                1
# 310             0              0                 0                0
# 408             1              1                 1                0
# 572             1              1                 2                0
#
#      Self_Emp_Label  Credit_history_Label  Property_area_Label
# 244               0                     1                    1
# ...

# %%
y_train.head()
# Out:
# 244    Y
# 393    Y
# 310    Y
# 408    N
# 572    Y
# Name: Loan_status_1, dtype: object

# %% [markdown]
# Model building

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_reg = LogisticRegression()

# %%
logistic_reg.fit(X_train,y_train)
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:460: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %% [markdown]
# Predections

# %%
y_pred = logistic_reg.predict(X_test)

# %%
# Evalution 
from sklearn.metrics import accuracy_score

# %%
#Accuracy

# %%
accuracy = accuracy_score(y_test, y_pred)

# %%
accuracy
# Out:
# 0.8078817733990148

# %% [markdown]
# Confusion Metrices

# %%
from sklearn.metrics import confusion_matrix

# %%
con_metrix = confusion_matrix(y_test,y_pred)

# %%
con_metrix
# Out:
# array([[ 35,  37],
#        [  2, 129]], dtype=int64)

# %% [markdown]
# Report

# %%
from sklearn.metrics import classification_report

# %%
class_report = classification_report(y_test,y_pred)

# %%
print(class_report)
# Out:
#               precision    recall  f1-score   support
#
#            N       0.95      0.49      0.64        72
#            Y       0.78      0.98      0.87       131
#
#     accuracy                           0.81       203
#    macro avg       0.86      0.74      0.76       203
# weighted avg       0.84      0.81      0.79       203

# %%
# Visualize

# %%
sns.heatmap(con_metrix, annot=True, fmt='d',cmap='Purples')
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.show()

# %%
#Decision Tree, Random Forest, Adaboost

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier

# %%
dtree = DecisionTreeClassifier(random_state=43)

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=43)

# %%
y_pres_dt = dtree.predict(X_test)

# %%
accuracy_dt = accuracy_score(y_test,y_pres_dt)

# %%
accuracy_dt
# Out:
# 0.6945812807881774

# %%
#Random Forest

# %%
rf = RandomForestClassifier(n_estimators= 100, random_state = 48)

# %%
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=48)

# %%
y_pred_rf = rf.predict(X_test)

# %%
accuracy_score_rf = accuracy_score(y_test, y_pred_rf)

# %%
accuracy_score_rf
# Out:
# 0.8029556650246306

# %%
#Adaboost

# %%
ab = AdaBoostClassifier(n_estimators=100, random_state = 40) #

# %%
ab.fit(X_train, y_train)
# Out:
# AdaBoostClassifier(n_estimators=100, random_state=40)

# %%
y_pred_ab = ab.predict(X_test)

# %%
accuracy_score_ab = accuracy_score(y_pred, y_pred_ab)

# %%
accuracy_score_ab
# Out:
# 0.9014778325123153

# %%
print("Accuracy of Logestic Regresion - ", accuracy)
print("Accuracy of Decision Tree - ", accuracy_dt)
print("Accuracy of Random Forest - ", accuracy)
print("Accuracy of Decision Tree - ", accuracy_dt)
# Out:
# Accuracy of Logestic Regresion -  0.8078817733990148
# Accuracy of Decision Tree -  0.6945812807881774
# Accuracy of Random Forest -  0.8078817733990148
# Accuracy of Decision Tree -  0.6945812807881774
